# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# !pwd
# Out:
# /home/ashun/Projects/mmsegmentation/tools/diffusemade

# %%
ann1 = '../../data/DiffuseMade_test5/test_minmax/cross_dir/train/00000077.png'
ann2 = '../../data/DiffuseMade_test5/test_minmax/ann_dir/train/00000077.png'

# %%
a1 = cv2.imread(ann1, 0)
a2 = cv2.imread(ann2, 0)

# %%
a1 = a1.astype(np.float32)
a2 = a2.astype(np.float32)

# %%
am = (2 * a1 * a2) / (a1 + a2)

# %%
plt.imshow(am)

# %%
import PIL.Image
img = '../../data/DiffuseMade_test5/test_minmax/img_dir/train/00000077.png'

PIL.Image.open(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
am2 = am.copy()
am2[am2 < 0.2 * 255] = 0
plt.imshow(am2)

# %%
plt.imshow(a2)
plt.show()
plt.imshow(a1)
plt.show()
plt.imshow(am)
plt.show()
